# %%
from presidio_analyzer import AnalyzerEngine, RecognizerResult
from presidio_anonymizer import AnonymizerEngine
from presidio_anonymizer.entities.engine.result import EngineResult

from typing import Iterator, List, Optional, Union, Dict, Iterable
from dataclasses import dataclass
import collections

# %%
import pandas as pd

# %%
@dataclass
class DictAnalyzerResult:
    key: str
    value: Union[str, List[str]]
    recognizer_results: Union[List[RecognizerResult], List[List[RecognizerResult]]]

# %%
class DictAnalyzerEngine(AnalyzerEngine):
    def analyze_dict(self, input_dict: Dict[str, str], **kwargs) -> Iterator[DictAnalyzerResult]:
        for key, value in input_dict.items():
            results = self.analyze(text=value, **kwargs) if isinstance(value, str) else []
            yield DictAnalyzerResult(key=key, value=value, recognizer_results=results) 
            
analyzer = DictAnalyzerEngine()

# %%
class DictAnonymizerEngine(AnonymizerEngine):
    
    def anonymize_dict(self, analyzer_results:Iterator[DictAnalyzerResult],**kwargs) -> Dict[str, str]:
        """ Run over all key, values and anonymize given the analyzer output for this cell. 
        Return the original data structure, with anonymized PII entities.
        """
 
        return_dict = {}
        for result in analyzer_results:
            if isinstance(result.value, str):
                resp = self.anonymize(text=result.value, analyzer_results=result.recognizer_results, **kwargs)
                return_dict[result.key] = resp.text              
            else:
                return_dict[result.key] = result.value             

        return return_dict
anonymizer = DictAnonymizerEngine()

# %% [markdown]
# Analyze

# %%
simple_dict = {"a":"My name is Robert", "b":"I live in Maine","c":5,"d":None}
simple_dict_results = analyzer.analyze_dict(simple_dict,language="en")
simple_dict_results = list(simple_dict_results)
print(simple_dict_results)
# Out:
# [2021-05-18 16:21:45,485] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 16:21:45,488] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'name'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 16:21:45,489] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 16:21:45,490] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Robert'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 16:21:45,511] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'I'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 16:21:45,512] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'live'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 16:21:45,512] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'in'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 16:21:45,512] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Maine'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [DictAnalyzerResult(key='a', value='My name is Robert', recognizer_results=[type: PERSON, start: 11, end: 17, score: 0.85]), DictAnalyzerResult(key='b', value='I live in Maine', recognizer_results=[type: LOCATION, start: 10, end: 15, score: 0.85]), DictAnalyzerResult(key='c', value=5, recognizer_results=[]), DictAnalyzerResult(key='d', value=None, recognizer_results=[])]

# %% [markdown]
# Anonymize

# %%
# One result
one_resp = anonymizer.anonymize(text=simple_dict_results[0].value, 
                                analyzer_results= simple_dict_results[0].recognizer_results)
print(one_resp.text)


# All results

resp = anonymizer.anonymize_dict(simple_dict_results)
print(resp)
# Out:
# My name is <PERSON>
# {'a': 'My name is <PERSON>', 'b': 'I live in <LOCATION>', 'c': 5, 'd': None}

# %% [markdown]
# ## Option 2

# %%
class DictAnalyzerEngine(AnalyzerEngine):
    def analyze_list(
        self, list_of_texts: Iterable[str], key: str = None, **kwargs
    ) -> List[List[RecognizerResult]]:
        list_results = []
        for text in list_of_texts:
            results = self.analyze(text=text, **kwargs) if isinstance(text, str) else []
            list_results.append(results)

        return list_results

    def analyze_dict(
        self, input_dict: Dict[str, Union[str, Iterable[str]]], **kwargs
    ) -> Iterator[DictAnalyzerResult]:

        for key, value in input_dict.items():
            if not value:
                results = []
            else:
                if isinstance(value, str):
                    results: List[RecognizerResult] = self.analyze(text=value, **kwargs)
                elif isinstance(value, collections.Iterable):
                    results: List[List[RecognizerResult]] = self.analyze_list(
                        list_of_texts=value, key=key, **kwargs
                    )
                else:
                    results= []

            yield DictAnalyzerResult(key=key, value=value, recognizer_results=results)
analyzer = DictAnalyzerEngine()

# %%
class DictAnonymizerEngine(AnonymizerEngine):
    
    def anonymize_list(self, texts:List[str], recognizer_results_list: List[List[RecognizerResult]], **kwargs) -> List[EngineResult]:
        return_list = []
        for text, recognizer_results in zip(texts, recognizer_results_list):
            if isinstance(text,str):
                res = self.anonymize(text=text,analyzer_results=recognizer_results,**kwargs)
                return_list.append(res.text)
            else:
                return_list.append(text)
           
        return return_list
    
    
    def anonymize_dict(self, analyzer_results: Iterator[DictAnalyzerResult],**kwargs) -> Dict[str, str]:
        """ Run over all key, values and anonymize given the analyzer output for this cell. 
        Return the original data structure, with anonymized PII entities.
        """
 
        return_dict = {}
        for result in analyzer_results:
            if isinstance(result.value, str):
                resp = self.anonymize(text=result.value, analyzer_results=result.recognizer_results, **kwargs)
                return_dict[result.key] = resp.text
            elif isinstance(result.value, collections.Iterable):
                
                anonymize_respones = self.anonymize_list(texts=result.value,
                                                         recognizer_results_list=result.recognizer_results, 
                                                         **kwargs)
                return_dict[result.key] = anonymize_respones 
            else:
                return_dict[result.key] = result.value
        return return_dict

anonymizer = DictAnonymizerEngine()

# %%
simple_dict = {"a":"My name is Robert", "b":"I live in Maine"}
simple_dict_results = analyzer.analyze_dict(simple_dict,language="en")
anonymizer_results = anonymizer.anonymize_dict(simple_dict_results)
print(anonymizer_results)
# Out:
# [2021-05-18 17:51:17,161] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:17,162] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'name'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:17,163] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:17,163] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Robert'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:17,170] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'I'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:17,170] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'live'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:17,171] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'in'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:17,171] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Maine'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# {'a': 'My name is <PERSON>', 'b': 'I live in <LOCATION>'}

# %% [markdown]
# Json with lists

# %%
json_w_lists = {"a": "My name is Robert",
                "b": ["My phone is 054-3332111", "5"],
                "c": 5
}
json_w_lists_results = analyzer.analyze_dict(json_w_lists,language="en")
json_w_lists_results = list(json_w_lists_results)
print(json_w_lists_results)
anonymizer.anonymize_dict(json_w_lists_results)
# Out:
# [2021-05-18 17:51:17,188] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:17,189] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'name'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:17,190] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:17,191] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Robert'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:17,198] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:17,199] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'phone'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:17,200] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:17,200] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token '054'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:17,201] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token '-'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:17,202] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token '3332111'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:17,209] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token '5'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [DictAnalyzerResult(key='a', value='My name is Robert', recognizer_results=[type: PERSON, start: 11, end: 17, score: 0.85]), DictAnalyzerResult(key='b', value=['My phone is 054-3332111', '5'], recognizer_results=[[type: PHONE_NUMBER, start: 12, end: 23, score: 0.85, type: US_DRIVER_LICENSE, start: 16, end: 23, score: 0.01], []]), DictAnalyzerResult(key='c', value=5, recognizer_results=[])]
# {'a': 'My name is <PERSON>', 'b': ['My phone is <PHONE_NUMBER>', '5'], 'c': 5}

# %% [markdown]
# Test on pandas data frames

# %%
iris = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv')
dataset_len = len(iris)

new_col = ["My name is Morris" for _ in range(dataset_len)]
iris["new_col"] = new_col

iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species  \
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
#
#              new_col
# 0  My name is Morris
# 1  My name is Morris
# 2  My name is Morris
# 3  My name is Morris
# 4  My name is Morris

# %%
#Option 1: pd.to_dict
iris_dict = iris.to_dict(orient="list")

analyzer_results = analyzer.analyze_dict(iris_dict,language="en")
anonymized_results = anonymizer.anonymize_dict(analyzer_results)
new_iris = pd.DataFrame(anonymized_results)
new_iris
# Out:
# [2021-05-18 17:51:18,224] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,230] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,236] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,242] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,248] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,253] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,258] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,264] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,269] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,274] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,279] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,284] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,289] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,295] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,300] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,305] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,311] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,316] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,321] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,327] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,332] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,336] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,342] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,348] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,352] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,357] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,363] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,368] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,373] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,378] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,383] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,389] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,396] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,402] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,408] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,415] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,421] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,426] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,432] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,437] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,443] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,448] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,452] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,457] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,463] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,468] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,473] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,478] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,483] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,488] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,493] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'versicolor'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,499] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'versicolor'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,504] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'versicolor'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,509] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'versicolor'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,514] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'versicolor'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,519] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'versicolor'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,524] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'versicolor'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,530] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'versicolor'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,537] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'versicolor'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,546] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'versicolor'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,554] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'versicolor'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,563] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'versicolor'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,572] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'versicolor'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,580] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'versicolor'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,587] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'versicolor'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,594] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'versicolor'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,601] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'versicolor'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,608] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'versicolor'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,615] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'versicolor'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,621] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'versicolor'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,628] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'versicolor'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,634] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'versicolor'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,641] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'versicolor'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,648] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'versicolor'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,655] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'versicolor'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,661] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'versicolor'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,666] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'versicolor'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,672] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'versicolor'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,678] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'versicolor'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,683] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'versicolor'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,689] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'versicolor'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,694] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'versicolor'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,700] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'versicolor'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,705] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'versicolor'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,711] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'versicolor'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,716] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'versicolor'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,722] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'versicolor'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,729] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'versicolor'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,735] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'versicolor'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,741] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'versicolor'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,748] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'versicolor'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,755] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'versicolor'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,761] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'versicolor'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,767] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'versicolor'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,772] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'versicolor'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,779] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'versicolor'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,786] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'versicolor'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,792] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'versicolor'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,799] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'versicolor'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,805] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'versicolor'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,810] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'virginica'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,817] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'virginica'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,822] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'virginica'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,829] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'virginica'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,835] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'virginica'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,841] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'virginica'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,848] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'virginica'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,854] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'virginica'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,859] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'virginica'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,866] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'virginica'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,872] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'virginica'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,879] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'virginica'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,885] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'virginica'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,892] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'virginica'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,898] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'virginica'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,904] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'virginica'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,910] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'virginica'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,916] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'virginica'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,921] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'virginica'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,927] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'virginica'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,932] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'virginica'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,937] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'virginica'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,941] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'virginica'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,947] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'virginica'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,952] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'virginica'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,957] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'virginica'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,962] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'virginica'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,967] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'virginica'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,972] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'virginica'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,977] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'virginica'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,983] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'virginica'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,988] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'virginica'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,993] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'virginica'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:18,998] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'virginica'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:19,004] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'virginica'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:19,009] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'virginica'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:19,016] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'virginica'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:19,022] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'virginica'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:19,029] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'virginica'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:19,035] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'virginica'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:19,040] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'virginica'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:19,047] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'virginica'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:19,052] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'virginica'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:19,058] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'virginica'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:19,063] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'virginica'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:19,068] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'virginica'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:19,073] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'virginica'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:19,078] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'virginica'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:19,083] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'virginica'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:19,088] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'virginica'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:19,095] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:19,096] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'name'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:19,096] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:19,097] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Morris'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:19,103] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:19,104] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'name'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:19,104] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:19,105] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Morris'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:19,111] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:19,112] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'name'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:19,112] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:19,113] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Morris'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:19,120] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:19,120] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'name'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:19,121] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:19,122] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Morris'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:19,128] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:19,129] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'name'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:19,130] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:19,130] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Morris'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:19,138] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:19,139] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'name'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:19,139] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:19,140] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Morris'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:19,148] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:19,149] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'name'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:19,150] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:19,151] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Morris'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:19,158] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:19,159] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'name'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:19,160] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:19,160] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Morris'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:19,168] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:19,169] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'name'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:19,170] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:19,170] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Morris'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:19,177] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:19,178] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'name'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:19,179] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:19,180] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Morris'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:19,186] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:19,187] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'name'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:19,188] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:19,188] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Morris'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# ...
# [2021-05-18 17:51:20,546] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:20,547] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'name'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:20,548] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:20,549] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Morris'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:20,556] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:20,557] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'name'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:20,558] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:20,559] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Morris'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:20,566] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:20,566] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'name'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:20,567] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:20,568] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Morris'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:20,574] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:20,575] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'name'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:20,576] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:20,576] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Morris'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:20,583] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:20,584] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'name'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:20,585] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:20,585] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Morris'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:20,593] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:20,594] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'name'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:20,595] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:20,595] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Morris'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:20,603] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:20,604] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'name'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:20,605] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:20,606] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Morris'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:20,613] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:20,615] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'name'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:20,615] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:20,616] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Morris'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:20,624] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:20,625] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'name'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:20,626] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:20,626] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Morris'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:20,636] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:20,637] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'name'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:20,638] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:20,639] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Morris'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:20,651] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:20,652] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'name'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:20,653] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:20,655] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Morris'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:20,664] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:20,666] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'name'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:20,667] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:20,667] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Morris'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:20,675] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:20,677] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'name'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:20,678] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:20,678] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Morris'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:20,686] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:20,687] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'name'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:20,688] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:20,689] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Morris'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:20,696] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:20,696] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'name'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:20,697] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:20,698] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Morris'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#                  new_col
# 0    My name is <PERSON>
# 1    My name is <PERSON>
# 2    My name is <PERSON>
# 3    My name is <PERSON>
# 4    My name is <PERSON>
# ..                   ...
# 145  My name is <PERSON>
# 146  My name is <PERSON>
# 147  My name is <PERSON>
# 148  My name is <PERSON>
# 149  My name is <PERSON>
#
# [150 rows x 6 columns]

# %%
#Option 1: pd.to_dict as columns
iris_dict = iris.to_dict(orient="records")
iris_dict
#iris_dict["sepal_length"]
anonymized = []
for record in iris_dict:
    analyzer_results = analyzer.analyze_dict(record, language="en")
    anonymized_results = anonymizer.anonymize_dict(analyzer_results)
    anonymized.append(anonymized_results)
pd.DataFrame(anonymized)
# Out:
# [2021-05-18 17:51:31,038] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,044] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,045] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'name'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,046] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,047] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Morris'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,053] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,059] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,060] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'name'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,060] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,061] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Morris'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,066] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,072] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,073] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'name'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,073] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,074] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Morris'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,079] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,085] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,086] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'name'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,086] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,088] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Morris'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,093] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,098] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,099] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'name'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,099] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,100] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Morris'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,106] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,111] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,112] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'name'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,112] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,113] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Morris'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,118] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,124] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,125] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'name'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,126] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,126] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Morris'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,134] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,141] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,142] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'name'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,143] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,143] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Morris'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,150] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,156] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,157] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'name'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,157] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,158] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Morris'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,163] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,169] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,170] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'name'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,170] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,171] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Morris'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,177] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,183] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,184] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'name'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,184] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,185] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Morris'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,191] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,197] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,198] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'name'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,198] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,199] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Morris'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,205] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,211] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,212] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'name'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,213] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,214] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Morris'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,221] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,228] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,229] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'name'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,229] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,230] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Morris'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,237] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,243] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,244] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'name'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,245] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,245] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Morris'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,254] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,260] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,261] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'name'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,261] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,262] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Morris'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,268] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,274] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,275] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'name'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,275] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,276] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Morris'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,281] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,288] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,289] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'name'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,289] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,290] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Morris'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,296] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,303] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,304] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'name'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,304] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,305] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Morris'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,312] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,319] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,321] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'name'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,322] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,322] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Morris'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,329] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,336] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,337] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'name'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,337] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,338] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Morris'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,344] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,351] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,352] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'name'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,352] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,353] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Morris'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,359] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,364] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,365] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'name'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,366] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,366] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Morris'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,373] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,380] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,381] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'name'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,382] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,383] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Morris'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,390] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,396] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,397] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'name'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,398] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,398] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Morris'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,405] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,412] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,413] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'name'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,414] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,415] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Morris'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,422] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,429] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,430] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'name'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,431] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,431] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Morris'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,439] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,445] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,446] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'name'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,447] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,447] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Morris'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,455] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,463] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,464] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'name'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,464] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,465] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Morris'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,473] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,479] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,480] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'name'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,481] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,481] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Morris'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,489] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,496] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,497] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'name'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,498] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,499] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Morris'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,507] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,515] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,517] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'name'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,519] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,520] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Morris'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,529] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,536] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,537] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'name'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,538] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,538] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Morris'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,546] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,555] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,556] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'name'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,557] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,558] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Morris'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,566] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,574] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,575] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'name'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,576] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,577] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Morris'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,584] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,591] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,591] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'name'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,592] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,593] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Morris'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,598] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,606] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,607] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'name'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,607] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,608] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Morris'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,614] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,621] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,622] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'name'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,622] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,623] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Morris'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,629] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,637] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,638] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'name'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,639] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,639] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Morris'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:31,648] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'setosa'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# ...
# [2021-05-18 17:51:33,281] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'virginica'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:33,288] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:33,290] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'name'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:33,290] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:33,291] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Morris'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:33,298] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'virginica'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:33,305] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:33,306] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'name'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:33,306] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:33,307] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Morris'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:33,314] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'virginica'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:33,320] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:33,321] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'name'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:33,321] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:33,322] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Morris'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:33,328] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'virginica'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:33,334] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:33,335] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'name'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:33,335] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:33,336] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Morris'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:33,342] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'virginica'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:33,348] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:33,349] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'name'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:33,350] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:33,350] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Morris'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:33,360] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'virginica'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:33,367] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:33,368] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'name'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:33,369] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:33,370] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Morris'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:33,377] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'virginica'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:33,383] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:33,384] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'name'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:33,385] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:33,385] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Morris'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:33,392] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'virginica'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:33,397] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:33,398] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'name'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:33,398] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:33,399] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Morris'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:33,407] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'virginica'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:33,414] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:33,415] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'name'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:33,416] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:33,417] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Morris'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:33,424] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'virginica'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:33,432] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:33,433] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'name'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:33,433] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:33,434] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Morris'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:33,441] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'virginica'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:33,448] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:33,449] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'name'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:33,450] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:33,451] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Morris'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:33,458] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'virginica'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:33,466] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'My'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:33,467] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'name'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:33,467] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'is'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
# [2021-05-18 17:51:33,468] [WARNING] [W108] The rule-based lemmatizer did not find POS annotation for the token 'Morris'. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#                  new_col
# 0    My name is <PERSON>
# 1    My name is <PERSON>
# 2    My name is <PERSON>
# 3    My name is <PERSON>
# 4    My name is <PERSON>
# ..                   ...
# 145  My name is <PERSON>
# 146  My name is <PERSON>
# 147  My name is <PERSON>
# 148  My name is <PERSON>
# 149  My name is <PERSON>
#
# [150 rows x 6 columns]
